# %%
#from pyrealsense2 import pyrealsense2 as rs
import numpy as np
import math
import time
from cv2 import cv2

# %%
for i in range(121,301):
    depth_image = cv2.imread(f".\\\data\\depthimagelabel\\d{i}.png",cv2.IMREAD_UNCHANGED)
    #print(depth_image)
    depth_colormap = cv2.applyColorMap(cv2.convertScaleAbs(depth_image, alpha=0.065), cv2.COLORMAP_JET)
    cv2.imwrite(f".\\\data\\depthimagelabel\\dcm{i}.png", depth_colormap)
    print(f"saved .\\\data\\depthimagelabel\\dcm{i}.png")
# Out:
# saved .\\data\depthimagelabel\dcm121.png
# saved .\\data\depthimagelabel\dcm122.png
# saved .\\data\depthimagelabel\dcm123.png
# saved .\\data\depthimagelabel\dcm124.png
# saved .\\data\depthimagelabel\dcm125.png
# saved .\\data\depthimagelabel\dcm126.png
# saved .\\data\depthimagelabel\dcm127.png
# saved .\\data\depthimagelabel\dcm128.png
# saved .\\data\depthimagelabel\dcm129.png
# saved .\\data\depthimagelabel\dcm130.png
# saved .\\data\depthimagelabel\dcm131.png
# saved .\\data\depthimagelabel\dcm132.png
# saved .\\data\depthimagelabel\dcm133.png
# saved .\\data\depthimagelabel\dcm134.png
# saved .\\data\depthimagelabel\dcm135.png
# saved .\\data\depthimagelabel\dcm136.png
# saved .\\data\depthimagelabel\dcm137.png
# saved .\\data\depthimagelabel\dcm138.png
# saved .\\data\depthimagelabel\dcm139.png
# saved .\\data\depthimagelabel\dcm140.png
# saved .\\data\depthimagelabel\dcm141.png
# saved .\\data\depthimagelabel\dcm142.png
# saved .\\data\depthimagelabel\dcm143.png
# ...

# %%
import os
for i in range(121,301):
    os.rename(f".\\\data\\depthimagelabel\\{i}.txt",f".\\\data\\depthimagelabel\\dcm{i}.txt")
